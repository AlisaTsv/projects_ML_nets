# %%
import pandas as pd
import numpy as np

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import precision_recall_curve, roc_curve, roc_auc_score, confusion_matrix
from sklearn.model_selection import cross_val_score, train_test_split

# %% [markdown]
# В проекте использованы реальные данные сотового оператора Мегафон
#
# Исходные данные представляют собой **2 таблицы**:
#
# **Первая таблица** содержит данные о пользователях и услугах, которые им предлагались. Каждому пользователю может быть сделано несколько предложений в разное время, каждое из которых он может или принять, или отклонить. id - id пользователя, vas_id - услуга, buy_time - время предложения, target - целевая переменная, показывает, согласился ли абонент на услугу. Первая таблица разделена на **train** (data_train) и **test** (data_test).
#
# **Вторая таблица** - информация о пользователях: анонимизированный набор признаков, характеризующий профиль потребления абонента. Эти данные привязаны к определенному времени, поскольку профиль абонента может меняться с течением времени. Из нее данные будут извлекаться по id пользователя.

# %%
import dask.dataframe as dd

# %% [markdown]
# Вес второй таблицы составляет 20 гигабайт, что усложняет работу. Для ее загрузки устанавливаем специальную библиотеку dask.
# Кроме того, в данном случае выбираю работу на собственном компьютере, а не на виртуальной машине google colab, так как объем памяти гугл-диска ограничен, скорость загрузки данных на него медленная.

# %%
df_train = pd.read_csv('/Users/features/data_train.csv')
df_train.head()
# Out:
#    Unnamed: 0       id  vas_id    buy_time  target
# 0           0   540968     8.0  1537131600     0.0
# 1           1  1454121     4.0  1531688400     0.0
# 2           2  2458816     1.0  1534107600     0.0
# 3           3  3535012     5.0  1535922000     0.0
# 4           4  1693214     1.0  1535922000     0.0

# %%
df_train.shape
# Out:
# (831653, 5)

# %% [markdown]
# Посмотрим на **соотношение классов 0 и 1**

# %%
df_train['target'].value_counts()
# Out:
# 0.0    771467
# 1.0     60186
# Name: target, dtype: int64

# %% [markdown]
# Выберем часть данных (насколько позволяет вычислительная мощность компьютера), предварительно изменив соотношение классов.

# %%
df_train_0 = df_train.loc[df_train['target'] == 0]

# %%
df_train_0['target'].value_counts()
# Out:
# 0.0    771467
# Name: target, dtype: int64

# %%
df_train_0 = df_train_0.sample(frac = 0.025, random_state = 1)

# %%
df_train_0.shape
# Out:
# (19287, 5)

# %%
df_train_1 = df_train.loc[df_train['target'] == 1]

# %%
df_train_1.shape
# Out:
# (60186, 5)

# %%
df_train_1 = df_train_1.sample(frac = 0.35, random_state = 1)

# %%
df_train_1.shape
# Out:
# (21065, 5)

# %% [markdown]
# Получаем **объединенный датасет**,  удаляем лишние столбцы с индексами

# %%
frames = [df_train_0, df_train_1]
df_train = pd.concat(frames)

# %%
df_train.shape
# Out:
# (40352, 5)

# %%
from sklearn.utils import shuffle

# %%
df_train = shuffle(df_train)

# %%
df_train = df_train.drop(df_train.columns[0], axis=1)

# %%
df_train.head(3)
# Out:
#              id  vas_id    buy_time  target
# 223664  3330027     4.0  1541365200     1.0
# 688341  2650728     6.0  1546203600     0.0
# 354454   347992     6.0  1532898000     1.0

# %% [markdown]
# Теперь нам необходимо дополнить датасет признаками: у нас есть таблица с признаками (анонимизированными), нужно выбрать из нее данные нужных пользователей

# %%
df_features = dd.read_csv('/Users/features/features.csv', sep='\t')

# %%
df_features = df_features.drop(df_features.columns[0], axis=1)

# %% [markdown]
# Признаков более 250, это, вероятно, избыточное количество. В качестве вынужденной меры случайным образом, но относительно равномерно, избавлюсь от значительной части признаков (иначе вычисления не производятся при доступной мощности).

# %%
list_of_cols = np.arange(0, 252, 12) 
list_of_cols
# Out:
# array([  0,  12,  24,  36,  48,  60,  72,  84,  96, 108, 120, 132, 144,
#        156, 168, 180, 192, 204, 216, 228, 240])

# %%
df_features = df_features[['id', 'buy_time','0', '12', '24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144', '156', '168', '180', '192', '204', '216', '228', '240', '252']]

# %%
df_features.head(10)
# Out:
#         id    buy_time           0         12        24        36         48  \
# 0  2013026  1531688400   18.910029  -2.558912 -0.009327 -0.700765 -10.717958
# 1  2014722  1539550800   36.690029  -2.558912 -0.009327 -0.700765 -10.717958
# 2  2015199  1545598800  -67.019971  -2.558912 -0.009327  1.839235 -10.716588
# 3  2021765  1534107600    7.010029  -2.558912 -0.009327 -0.700765 -10.717958
# 4  2027465  1533502800  -90.439971  -2.558912 -0.009327 -0.700765 -10.717958
# 5  2028410  1534107600  -96.799971  -2.558912 -0.009327 -0.700765 -10.717958
# 6  2030773  1544994000  284.560029  -2.558912 -0.009327 -0.700765 -10.717958
# 7  2032337  1537736400   92.550029  31.341088 -0.009327 -0.700765 -10.678718
# 8  2033486  1545598800  -93.749971  -2.558912 -0.009327 -0.700765 -10.717958
# 9  2034066  1544389200  228.520029  -2.558912 -0.009327 -0.700765 -10.717958
#
#          60        72        84  ...         144        156        168  \
# 0 -0.265234  -2.60662 -0.134088  ...  -70.470802  -2.548856 -51.984826
# 1 -0.265234  -2.60662 -0.134088  ...   57.495858  35.451144 -51.984826
# 2  0.244766  -2.60662 -0.134088  ...  -43.587468  -2.548856  12.548504
# 3 -0.265234  -2.60662 -0.134088  ...   11.079198  -2.548856 -51.984826
# 4 -0.265234  -2.60662 -0.134088  ... -116.020802  52.451144 -51.984826
# 5  0.054766  -2.60662 -0.134088  ...   -4.070802  -2.548856 -18.551496
# 6 -0.265234  -2.60662 -0.134088  ... -116.020802  26.451144 -51.984826
# 7  0.704766  31.29338 -0.134088  ... -100.404136  -2.548856 -37.718159
# 8  0.034766  -2.60662 -0.134088  ...  -77.420800  -2.548856 -45.834824
# 9  0.174766  -2.60662 -0.134088  ...    2.395862  -2.548856 -51.984826
#
#        180       192       204       216        228          240  252
# 0 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -512.437331  0.0
# 1 -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -509.437331  0.0
# 2 -0.00189 -0.466683  0.039208 -0.000083 -19.302382  -512.437331  0.0
# 3 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -512.437331  1.0
# 4 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -496.437331  0.0
# 5 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -512.437331  0.0
# 6 -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -512.437331  1.0
# 7 -0.00189 -0.466683  0.039208 -0.000083 -33.302382  1694.562669  1.0
# 8 -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -510.437331  1.0
# 9 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -512.437331  0.0
#
# [10 rows x 24 columns]

# %%
df_train_id = df_train['id']
df_train_id.head(3)
# Out:
# 223664    3330027
# 688341    2650728
# 354454     347992
# Name: id, dtype: int64

# %% [markdown]
# Находим нужных пользователей:

# %%
df_features_train = df_features[df_features['id'].isin(df_train_id)]
df_features_train.head(5)
# Out:
#           id    buy_time          0        12        24        36         48  \
# 19   2070757  1540760400 -96.799971 -2.558912 -0.009327 -0.700765 -10.717958
# 27   2085648  1539550800  68.440029 -2.558912 -0.009327 -0.700765 -10.711879
# 123  2508658  1537736400 -84.579971 -2.558912 -0.009327 -0.700765 -10.717958
# 224  2931982  1534107600 -96.799971 -2.558912 -0.009327 -0.700765 -10.717958
# 500  3749290  1534712400 -96.799971 -2.558912 -0.009327 -0.700765 -10.717958
#
#            60       72        84  ...         144        156         168  \
# 19  -0.265234 -2.60662 -0.134088  ... -116.020802  47.451144  -51.984826
# 27   0.214766 -2.60662 -0.134088  ...   14.829198  -2.548856  157.998514
# 123  0.284766 -2.60662 -0.134088  ...  -76.204132  -2.548856   15.081840
# 224 -0.005234 -2.60662 -0.134088  ...  -69.520802  -2.548856  -41.001493
# 500  0.234766 -2.60662 -0.134088  ...  -54.487469  -2.548856  -23.784826
#
#          180       192       204       216        228         240  252
# 19  -0.00189  0.533317  0.039208 -0.000083 -33.302382 -512.437331  1.0
# 27  -0.00189 -0.466683  0.039208 -0.000083 -30.302382 -512.437331  0.0
# 123 -0.00189 -0.466683  0.039208 -0.000083 -33.302382 -512.437331  0.0
# 224 -0.00189  0.533317  0.039208 -0.000083  -1.302382 -511.437331  1.0
# 500 -0.00189 -0.466683  0.039208 -0.000083 -33.302382 -512.437331  1.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Осуществляем соединение таблиц по id и времени

# %%
df_train_feat = dd.multi.merge_asof(df_train, df_features_train.sort_values('buy_time'), by='id', on='buy_time', direction='nearest')

# %% [markdown]
# Сохраняем данные: **объединенный train датасет с профилем выбранных пользователей**

# %%
df_train_feat.to_csv('/Users/features/train_feat_balanced.csv', index=False, single_file=True)
# Out:
# ['C:/Users/features/train_feat_balanced.csv']

# %%
df_train_feat = pd.read_csv('/Users/features/train_feat_balanced.csv')

# %%
df_train_feat['target'].value_counts()
# Out:
# 1.0    21065
# 0.0    19287
# Name: target, dtype: int64

# %%
df_train_feat.head(20)
# Out:
#       buy_time       id  vas_id  target           0        12        24  \
# 0   1531083600   630641     4.0     0.0  -92.559971 -2.558912 -0.009327
# 1   1531083600  3982682     2.0     0.0   38.230029 -2.558912 -0.009327
# 2   1531083600  2784493     1.0     1.0  -96.799971 -2.558912 -0.009327
# 3   1531083600   921434     2.0     0.0  -96.799971 -2.558912 -0.009327
# 4   1531083600  2914443     1.0     0.0  -45.959971 -2.558912 -0.009327
# 5   1531083600  3577906     2.0     0.0  -81.959971 -2.558912 -0.009327
# 6   1531083600  3474769     2.0     0.0   -2.549971 -2.558912 -0.009327
# 7   1531083600  4214780     2.0     0.0  497.950029 -2.558912 -0.009327
# 8   1531083600   338838     2.0     0.0  -96.799971 -2.558912 -0.009327
# 9   1531083600   966530     4.0     1.0  -71.379971 -2.558912 -0.009327
# 10  1531083600   519166     2.0     1.0  -67.119971 -2.558912 -0.009327
# 11  1531083600   698645     6.0     1.0  -96.799971 -2.558912 -0.009327
# 12  1531083600  1781737     2.0     0.0  -91.719971 -2.558912 -0.009327
# 13  1531083600  1609444     4.0     1.0   23.060029 -2.558912 -0.009327
# 14  1531083600  2980291     4.0     0.0  -82.399971 -2.558912 -0.009327
# 15  1531083600  1935977     4.0     1.0  -48.049971 -2.558912 -0.009327
# 16  1531083600  1077783     1.0     1.0   75.190029 -2.558912 -0.009327
# 17  1531083600  1869949     2.0     1.0  418.030029 -2.558912 -0.009327
# 18  1531083600  2546313     4.0     1.0  -96.799971 -2.558912 -0.009327
# 19  1531083600  3834255     2.0     0.0  445.570029 -2.558912 -0.009327
#
#            36         48        60  ...         144         156         168  \
# 0   -0.700765 -10.717958  0.284766  ...  200.845868   -2.548856  -51.984826
# 1    1.419235 -10.717958  0.314766  ...   43.212538   -2.548856  -13.301496
# 2   -0.700765 -10.717958  0.144766  ...  -96.187470   -2.548856  -41.734826
# 3   -0.700765 -10.717958 -0.265234  ... -116.020802   -2.548856  -51.984826
# 4   -0.700765 -10.717958 -0.265234  ... -104.270803   -2.548856  -47.234827
# 5   14.139235 -10.717958 -0.005234  ...  559.895798   -2.548856  -51.818159
# 6   -0.700765 -10.717958 -0.155234  ...   28.262538   -2.548856   28.448508
# 7    0.829235 -10.717958 -0.155234  ...  297.879198   -2.548856   87.681844
# 8   -0.700765 -10.717958  0.514766  ...  310.762528   -2.548856   23.481844
# 9   -0.700765 -10.717958 -0.265234  ...  192.695868   -2.548856   35.048504
# 10  -0.700765 -10.544390 -0.265234  ...  -97.087470   -2.548856  -51.984826
# 11  -0.700765 -10.717958 -0.265234  ... -115.437468   -2.548856  -51.984826
# 12  -0.700765 -10.717958 -0.265234  ... -111.620802  123.451144  -51.984826
# 13  -0.700765 -10.645836 -0.265234  ...  -91.537472   -2.548856  125.965174
# 14   3.539235 -10.717958  0.064766  ...   47.845868   -2.548856  -51.984826
# 15  -0.700765 -10.717958 -0.265234  ... -116.020802   -2.548856  -51.984826
# 16  -0.700765 -10.664331  0.234766  ...  -12.920802   -2.548856    9.598506
# 17   3.539235 -10.717958 -0.185234  ...   23.779198   -2.548856   19.215179
# 18  -0.700765 -10.717958 -0.265234  ... -116.020802   54.451144  -51.984826
# 19  -0.700765 -10.717958  0.244766  ...  170.679178   -2.548856   55.348504
#
#         180       192       204       216        228          240  252
# 0  -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -105.437331  1.0
# 1  -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -512.437331  1.0
# 2  -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -446.437331  0.0
# 3  -0.00189  0.533317  0.039208 -0.000083 -33.302382  -511.437331  0.0
# 4  -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -512.437331  0.0
# 5  -0.00189  0.533317  0.039208 -0.000083 -33.302382  3256.562669  0.0
# 6  -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -504.437331  0.0
# 7  -0.00189 -0.466683  0.039208 -0.000083  -2.302382  -363.437331  1.0
# 8  -0.00189 -0.466683  0.039208 -0.000083 -33.302382  8312.562669  0.0
# 9  -0.00189  0.533317  0.039208 -0.000083 -33.302382   346.562669  1.0
# 10 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -506.437331  0.0
# 11 -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -512.437331  0.0
# 12 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -279.437331  0.0
# 13 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -327.437331  0.0
# 14 -0.00189  0.533317  0.039208 -0.000083 -33.302382   521.562669  0.0
# 15 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -512.437331  0.0
# 16 -0.00189 -0.466683  0.039208 -0.000083 -33.302382  -488.437331  0.0
# 17 -0.00189  0.533317  0.039208 -0.000083 -33.302382    55.562669  0.0
# 18 -0.00189  0.533317  0.039208 -0.000083 -33.302382  2771.562669  0.0
# 19 -0.00189  0.533317  0.039208 -0.000083 -33.302382  -509.437331  0.0
#
# [20 rows x 26 columns]

# %%
df_train_feat.shape
# Out:
# (40352, 26)

# %% [markdown]
# Столбец '252' - выглядит как target. Это вызывает вопросы. С target он не совпадает. Возможно, стоит его убрать. Попробуем его оставить.

# %% [markdown]
# Здесь нам необходимо провести **проверку на пропуски**:

# %%
df_train_feat.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Приведем признаки к **единому масштабу**:

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler()

# %%
df_train_feat_scaled = scaler.fit_transform(df_train_feat[['0', '12', '24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144', '156', '168', '180', '192', '204', '216', '228', '240', '252']])

# %%
scaled = pd.DataFrame(df_train_feat_scaled, columns = ['0', '12', '24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144', '156', '168', '180', '192', '204', '216', '228', '240', '252'])
scaled.head(3)
# Out:
#           0        12        24        36        48        60        72  \
# 0 -0.489226 -0.072862 -0.004978 -0.161858 -0.032645  0.876874 -0.073895
# 1  0.194283 -0.072862 -0.004978  0.339066 -0.032645  0.969580 -0.073895
# 2 -0.511384 -0.072862 -0.004978 -0.161858 -0.032645  0.444245 -0.073895
#
#         84        96       108  ...       144      156       168       180  \
# 0 -0.01378 -0.061762 -0.249480  ...  1.100575 -0.17601 -0.599613 -0.010451
# 1 -0.01378 -0.061762  0.529213  ...  0.240201 -0.17601 -0.149743 -0.010451
# 2 -0.01378 -0.061762 -0.249480  ... -0.520654 -0.17601 -0.480410 -0.010451
#
#         192       204       216       228       240       252
# 0 -0.938542  0.204053 -0.004978 -0.033266 -0.059386  1.697322
# 1 -0.938542  0.204053 -0.004978 -0.033266 -0.317511  1.697322
# 2 -0.938542  0.204053 -0.004978 -0.033266 -0.275653 -0.580678
#
# [3 rows x 22 columns]

# %%
df_train_f = df_train_feat[['buy_time', 'id', 'vas_id']].copy()

# %%
df_train_feat_scaled = pd.concat([df_train_f, scaled], axis = 1)
df_train_feat_scaled.head(7)
# Out:
#      buy_time       id  vas_id         0        12        24        36  \
# 0  1531083600   630641     4.0 -0.489226 -0.072862 -0.004978 -0.161858
# 1  1531083600  3982682     2.0  0.194283 -0.072862 -0.004978  0.339066
# 2  1531083600  2784493     1.0 -0.511384 -0.072862 -0.004978 -0.161858
# 3  1531083600   921434     2.0 -0.511384 -0.072862 -0.004978 -0.161858
# 4  1531083600  2914443     1.0 -0.245694 -0.072862 -0.004978 -0.161858
# 5  1531083600  3577906     2.0 -0.433830 -0.072862 -0.004978  3.344612
# 6  1531083600  3474769     2.0 -0.018834 -0.072862 -0.004978 -0.161858
#
#          48        60        72  ...       144      156       168       180  \
# 0 -0.032645  0.876874 -0.073895  ...  1.100575 -0.17601 -0.599613 -0.010451
# 1 -0.032645  0.969580 -0.073895  ...  0.240201 -0.17601 -0.149743 -0.010451
# 2 -0.032645  0.444245 -0.073895  ... -0.520654 -0.17601 -0.480410 -0.010451
# 3 -0.032645 -0.822742 -0.073895  ... -0.628905 -0.17601 -0.599613 -0.010451
# 4 -0.032645 -0.822742 -0.073895  ... -0.564773 -0.17601 -0.544372 -0.010451
# 5 -0.032645 -0.019287 -0.073895  ...  3.060294 -0.17601 -0.597674 -0.010451
# 6 -0.032645 -0.482819 -0.073895  ...  0.158603 -0.17601  0.335792 -0.010451
#
#         192       204       216       228       240       252
# 0 -0.938542  0.204053 -0.004978 -0.033266 -0.059386  1.697322
# 1 -0.938542  0.204053 -0.004978 -0.033266 -0.317511  1.697322
# 2 -0.938542  0.204053 -0.004978 -0.033266 -0.275653 -0.580678
# 3  1.065482  0.204053 -0.004978 -0.033266 -0.316877 -0.580678
# 4 -0.938542  0.204053 -0.004978 -0.033266 -0.317511 -0.580678
# 5  1.065482  0.204053 -0.004978 -0.033266  2.072844 -0.580678
# 6 -0.938542  0.204053 -0.004978 -0.033266 -0.312437 -0.580678
#
# [7 rows x 25 columns]

# %% [markdown]
# Здесь мы могли бы снизить размерность признаков, но будем считать, что в данном случае количество признаков было и так достаточно уменьшено.

# %%
df_train_feat_scaled_time = df_train_feat_scaled

# %% [markdown]
# Изменим формат времени

# %%
import datetime

# %%
df_train_feat_scaled['buy_time'] = df_train_feat_scaled['buy_time'].apply(lambda x: datetime.datetime.fromtimestamp(x))

# %%
df_train_feat_scaled.head(3)
# Out:
#     buy_time       id  vas_id         0        12        24        36  \
# 0 2018-07-09   630641     4.0 -0.489226 -0.072862 -0.004978 -0.161858
# 1 2018-07-09  3982682     2.0  0.194283 -0.072862 -0.004978  0.339066
# 2 2018-07-09  2784493     1.0 -0.511384 -0.072862 -0.004978 -0.161858
#
#          48        60        72  ...       144      156       168       180  \
# 0 -0.032645  0.876874 -0.073895  ...  1.100575 -0.17601 -0.599613 -0.010451
# 1 -0.032645  0.969580 -0.073895  ...  0.240201 -0.17601 -0.149743 -0.010451
# 2 -0.032645  0.444245 -0.073895  ... -0.520654 -0.17601 -0.480410 -0.010451
#
#         192       204       216       228       240       252
# 0 -0.938542  0.204053 -0.004978 -0.033266 -0.059386  1.697322
# 1 -0.938542  0.204053 -0.004978 -0.033266 -0.317511  1.697322
# 2 -0.938542  0.204053 -0.004978 -0.033266 -0.275653 -0.580678
#
# [3 rows x 25 columns]

# %% [markdown]
# Подготовим **тестовый датасет**: выбираем из таблицы признаков необходимые id и объединение таблицы по id и buy_time

# %%
df_test = pd.read_csv('/Users/features/data_test.csv')
df_test.head(5)
# Out:
#    Unnamed: 0       id  vas_id    buy_time
# 0           0  3130519     2.0  1548018000
# 1           1  2000860     4.0  1548018000
# 2           2  1099444     2.0  1546808400
# 3           3  1343255     5.0  1547413200
# 4           4  1277040     2.0  1546808400

# %%
df_test = df_test.drop(df_test.columns[0], axis=1)

# %%
df_test_id = df_test['id']
df_test_id.head(7)
# Out:
# 0    3130519
# 1    2000860
# 2    1099444
# 3    1343255
# 4    1277040
# 5     720364
# 6    3195325
# Name: id, dtype: int64

# %%
df_features_test = df_features[df_features['id'].isin(df_test_id)]

# %%
df_test_feat = dd.multi.merge_asof(df_test, df_features_test.sort_values('buy_time'), by='id', on='buy_time', direction='nearest')

# %% [markdown]
# Сохраняем **тестовый датасет**

# %%
df_test_feat.to_csv('/Users/features/test_feat.csv', index=False, single_file=True)
# Out:
# ['C:/Users/features/test_feat.csv']

# %%
df_test_feat = pd.read_csv('/Users/features/test_feat.csv')

# %%
df_test_feat.shape
# Out:
# (71231, 25)

# %% [markdown]
# Проверяем **пропуски** в тестовом датасете, **масштабируем** признаки

# %%
df_test_feat.isnull().sum().sum()
# Out:
# 0

# %%
df_test_feat_scaled = scaler.transform(df_test_feat[['0', '12', '24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144', '156', '168', '180', '192', '204', '216', '228', '240', '252']])

# %%
scaled_2 = pd.DataFrame(df_test_feat_scaled, columns = ['0', '12', '24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144', '156', '168', '180', '192', '204', '216', '228', '240', '252'])
scaled_2.head(3)
# Out:
#           0        12        24        36        48        60        72  \
# 0 -0.433883 -0.072862 -0.004978 -0.161858 -0.032645 -0.822742 -0.073895
# 1  1.725187 -0.072862 -0.004978 -0.161858 -0.032645 -0.822742 -0.073895
# 2  0.108681 -0.072862 -0.004978 -0.161858 -0.032645  2.174763 -0.073895
#
#         84        96       108  ...       144      156       168       180  \
# 0 -0.01378 -0.061762  0.017363  ... -0.625721 -0.17601 -0.592829 -0.010451
# 1 -0.01378 -0.061762 -0.160462  ... -0.410673 -0.17601 -0.599613 -0.010451
# 2 -0.01378 -0.061762 -0.249480  ...  0.143957 -0.17601  0.354205 -0.010451
#
#         192       204       216       228       240       252
# 0  1.065482  0.204053 -0.004978 -0.033266 -0.317511  1.697322
# 1 -0.938542  0.204053 -0.004978 -0.033266 -0.313706 -0.580678
# 2  1.065482  0.204053 -0.004978 -0.033266 -0.317511 -0.580678
#
# [3 rows x 22 columns]

# %%
df_test_f = df_test_feat[['buy_time', 'id', 'vas_id']].copy()

# %%
df_test_feat_scaled = pd.concat([df_test_f, scaled_2], axis = 1)
df_test_feat_scaled.head(3)
# Out:
#      buy_time       id  vas_id         0        12        24        36  \
# 0  1546808400  1099444     2.0 -0.433883 -0.072862 -0.004978 -0.161858
# 1  1546808400  1277040     2.0  1.725187 -0.072862 -0.004978 -0.161858
# 2  1546808400  3726752     1.0  0.108681 -0.072862 -0.004978 -0.161858
#
#          48        60        72  ...       144      156       168       180  \
# 0 -0.032645 -0.822742 -0.073895  ... -0.625721 -0.17601 -0.592829 -0.010451
# 1 -0.032645 -0.822742 -0.073895  ... -0.410673 -0.17601 -0.599613 -0.010451
# 2 -0.032645  2.174763 -0.073895  ...  0.143957 -0.17601  0.354205 -0.010451
#
#         192       204       216       228       240       252
# 0  1.065482  0.204053 -0.004978 -0.033266 -0.317511  1.697322
# 1 -0.938542  0.204053 -0.004978 -0.033266 -0.313706 -0.580678
# 2  1.065482  0.204053 -0.004978 -0.033266 -0.317511 -0.580678
#
# [3 rows x 25 columns]

# %% [markdown]
# Изменяем формат времени

# %%
df_test_feat_scaled['buy_time'] = df_test_feat_scaled['buy_time'].apply(lambda x: datetime.datetime.fromtimestamp(x))

# %%
df_test_feat_scaled.head(3)
# Out:
#     buy_time       id  vas_id         0        12        24        36  \
# 0 2019-01-07  1099444     2.0 -0.433883 -0.072862 -0.004978 -0.161858
# 1 2019-01-07  1277040     2.0  1.725187 -0.072862 -0.004978 -0.161858
# 2 2019-01-07  3726752     1.0  0.108681 -0.072862 -0.004978 -0.161858
#
#          48        60        72  ...       144      156       168       180  \
# 0 -0.032645 -0.822742 -0.073895  ... -0.625721 -0.17601 -0.592829 -0.010451
# 1 -0.032645 -0.822742 -0.073895  ... -0.410673 -0.17601 -0.599613 -0.010451
# 2 -0.032645  2.174763 -0.073895  ...  0.143957 -0.17601  0.354205 -0.010451
#
#         192       204       216       228       240       252
# 0  1.065482  0.204053 -0.004978 -0.033266 -0.317511  1.697322
# 1 -0.938542  0.204053 -0.004978 -0.033266 -0.313706 -0.580678
# 2  1.065482  0.204053 -0.004978 -0.033266 -0.317511 -0.580678
#
# [3 rows x 25 columns]

# %% [markdown]
# Начнем **обучать модели**.
# Выберем модели, которые хороши для бинарной классификации с множеством признаков, - CatBoost и XGBoost.

# %%
X = df_train_feat_scaled
y = df_train_feat['target']

# %%
df_train_feat['target'].value_counts()
# Out:
# 1.0    21065
# 0.0    19287
# Name: target, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 1)

# %%
from catboost import CatBoostClassifier

# %%
model_cat = CatBoostClassifier(
    random_seed=1,
    iterations=200,
    learning_rate=0.05
)

model_cat.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6489658	total: 219ms	remaining: 43.6s
# 1:	learn: 0.6152063	total: 257ms	remaining: 25.4s
# 2:	learn: 0.5863056	total: 292ms	remaining: 19.2s
# 3:	learn: 0.5586754	total: 311ms	remaining: 15.2s
# 4:	learn: 0.5299183	total: 325ms	remaining: 12.7s
# 5:	learn: 0.5057343	total: 336ms	remaining: 10.9s
# 6:	learn: 0.4860171	total: 345ms	remaining: 9.52s
# 7:	learn: 0.4701553	total: 354ms	remaining: 8.5s
# 8:	learn: 0.4553110	total: 363ms	remaining: 7.7s
# 9:	learn: 0.4421273	total: 372ms	remaining: 7.07s
# 10:	learn: 0.4289106	total: 382ms	remaining: 6.56s
# 11:	learn: 0.4183124	total: 391ms	remaining: 6.13s
# 12:	learn: 0.4062986	total: 401ms	remaining: 5.76s
# 13:	learn: 0.3972990	total: 415ms	remaining: 5.51s
# 14:	learn: 0.3915413	total: 428ms	remaining: 5.28s
# 15:	learn: 0.3854717	total: 439ms	remaining: 5.04s
# 16:	learn: 0.3804127	total: 447ms	remaining: 4.82s
# 17:	learn: 0.3744607	total: 457ms	remaining: 4.62s
# 18:	learn: 0.3679881	total: 467ms	remaining: 4.44s
# 19:	learn: 0.3651143	total: 476ms	remaining: 4.29s
# 20:	learn: 0.3611486	total: 486ms	remaining: 4.14s
# 21:	learn: 0.3582827	total: 496ms	remaining: 4.01s
# 22:	learn: 0.3547100	total: 505ms	remaining: 3.89s
# 23:	learn: 0.3517572	total: 515ms	remaining: 3.77s
# 24:	learn: 0.3501351	total: 524ms	remaining: 3.67s
# 25:	learn: 0.3487296	total: 534ms	remaining: 3.57s
# 26:	learn: 0.3468063	total: 543ms	remaining: 3.48s
# 27:	learn: 0.3449928	total: 552ms	remaining: 3.39s
# 28:	learn: 0.3427188	total: 562ms	remaining: 3.31s
# 29:	learn: 0.3411980	total: 571ms	remaining: 3.23s
# 30:	learn: 0.3392637	total: 580ms	remaining: 3.16s
# 31:	learn: 0.3381323	total: 590ms	remaining: 3.1s
# 32:	learn: 0.3374140	total: 598ms	remaining: 3.03s
# 33:	learn: 0.3364274	total: 632ms	remaining: 3.08s
# 34:	learn: 0.3357838	total: 642ms	remaining: 3.02s
# 35:	learn: 0.3350990	total: 651ms	remaining: 2.97s
# 36:	learn: 0.3342376	total: 661ms	remaining: 2.91s
# 37:	learn: 0.3335571	total: 670ms	remaining: 2.86s
# 38:	learn: 0.3331360	total: 680ms	remaining: 2.81s
# 39:	learn: 0.3324591	total: 690ms	remaining: 2.76s
# 40:	learn: 0.3317925	total: 699ms	remaining: 2.71s
# 41:	learn: 0.3314500	total: 708ms	remaining: 2.66s
# 42:	learn: 0.3305203	total: 717ms	remaining: 2.62s
# 43:	learn: 0.3298937	total: 726ms	remaining: 2.57s
# 44:	learn: 0.3284767	total: 735ms	remaining: 2.53s
# 45:	learn: 0.3280517	total: 745ms	remaining: 2.49s
# 46:	learn: 0.3278381	total: 754ms	remaining: 2.46s
# 47:	learn: 0.3276670	total: 764ms	remaining: 2.42s
# 48:	learn: 0.3273889	total: 773ms	remaining: 2.38s
# 49:	learn: 0.3269402	total: 782ms	remaining: 2.35s
# 50:	learn: 0.3266246	total: 791ms	remaining: 2.31s
# 51:	learn: 0.3263182	total: 800ms	remaining: 2.28s
# 52:	learn: 0.3260259	total: 809ms	remaining: 2.24s
# 53:	learn: 0.3257700	total: 823ms	remaining: 2.22s
# 54:	learn: 0.3255310	total: 833ms	remaining: 2.2s
# 55:	learn: 0.3252978	total: 846ms	remaining: 2.18s
# 56:	learn: 0.3250884	total: 862ms	remaining: 2.16s
# 57:	learn: 0.3246640	total: 878ms	remaining: 2.15s
# 58:	learn: 0.3245153	total: 889ms	remaining: 2.13s
# 59:	learn: 0.3240069	total: 899ms	remaining: 2.1s
# 60:	learn: 0.3238893	total: 908ms	remaining: 2.07s
# 61:	learn: 0.3236240	total: 917ms	remaining: 2.04s
# 62:	learn: 0.3235260	total: 927ms	remaining: 2.02s
# 63:	learn: 0.3233698	total: 936ms	remaining: 1.99s
# 64:	learn: 0.3232593	total: 945ms	remaining: 1.96s
# 65:	learn: 0.3225027	total: 954ms	remaining: 1.94s
# 66:	learn: 0.3223605	total: 964ms	remaining: 1.91s
# 67:	learn: 0.3222590	total: 975ms	remaining: 1.89s
# 68:	learn: 0.3221273	total: 985ms	remaining: 1.87s
# 69:	learn: 0.3220155	total: 994ms	remaining: 1.84s
# 70:	learn: 0.3219157	total: 1s	remaining: 1.82s
# 71:	learn: 0.3217525	total: 1.01s	remaining: 1.8s
# 72:	learn: 0.3216489	total: 1.02s	remaining: 1.78s
# 73:	learn: 0.3215238	total: 1.03s	remaining: 1.76s
# 74:	learn: 0.3213636	total: 1.04s	remaining: 1.74s
# 75:	learn: 0.3211827	total: 1.06s	remaining: 1.72s
# 76:	learn: 0.3210884	total: 1.07s	remaining: 1.7s
# 77:	learn: 0.3210005	total: 1.07s	remaining: 1.68s
# 78:	learn: 0.3209509	total: 1.08s	remaining: 1.66s
# 79:	learn: 0.3208029	total: 1.1s	remaining: 1.65s
# 80:	learn: 0.3206672	total: 1.11s	remaining: 1.63s
# 81:	learn: 0.3206247	total: 1.12s	remaining: 1.61s
# 82:	learn: 0.3204766	total: 1.13s	remaining: 1.59s
# 83:	learn: 0.3203492	total: 1.14s	remaining: 1.57s
# 84:	learn: 0.3201957	total: 1.14s	remaining: 1.55s
# 85:	learn: 0.3201210	total: 1.16s	remaining: 1.53s
# 86:	learn: 0.3200635	total: 1.17s	remaining: 1.51s
# 87:	learn: 0.3199152	total: 1.18s	remaining: 1.5s
# 88:	learn: 0.3197668	total: 1.19s	remaining: 1.48s
# 89:	learn: 0.3196755	total: 1.2s	remaining: 1.46s
# 90:	learn: 0.3196101	total: 1.21s	remaining: 1.45s
# 91:	learn: 0.3195862	total: 1.22s	remaining: 1.43s
# 92:	learn: 0.3193504	total: 1.23s	remaining: 1.41s
# 93:	learn: 0.3193080	total: 1.24s	remaining: 1.4s
# 94:	learn: 0.3192432	total: 1.25s	remaining: 1.38s
# 95:	learn: 0.3191430	total: 1.26s	remaining: 1.36s
# 96:	learn: 0.3191371	total: 1.27s	remaining: 1.35s
# 97:	learn: 0.3190332	total: 1.28s	remaining: 1.33s
# 98:	learn: 0.3189616	total: 1.29s	remaining: 1.31s
# 99:	learn: 0.3189363	total: 1.3s	remaining: 1.3s
# 100:	learn: 0.3189116	total: 1.3s	remaining: 1.28s
# 101:	learn: 0.3187598	total: 1.31s	remaining: 1.26s
# 102:	learn: 0.3186903	total: 1.32s	remaining: 1.25s
# 103:	learn: 0.3186282	total: 1.33s	remaining: 1.23s
# 104:	learn: 0.3185396	total: 1.34s	remaining: 1.21s
# 105:	learn: 0.3182808	total: 1.35s	remaining: 1.2s
# 106:	learn: 0.3182061	total: 1.36s	remaining: 1.18s
# 107:	learn: 0.3178769	total: 1.37s	remaining: 1.17s
# 108:	learn: 0.3178125	total: 1.38s	remaining: 1.15s
# 109:	learn: 0.3175825	total: 1.39s	remaining: 1.14s
# 110:	learn: 0.3175004	total: 1.4s	remaining: 1.12s
# 111:	learn: 0.3174501	total: 1.41s	remaining: 1.1s
# 112:	learn: 0.3173555	total: 1.42s	remaining: 1.09s
# 113:	learn: 0.3173042	total: 1.43s	remaining: 1.08s
# 114:	learn: 0.3172602	total: 1.44s	remaining: 1.07s
# 115:	learn: 0.3171156	total: 1.45s	remaining: 1.05s
# 116:	learn: 0.3170181	total: 1.46s	remaining: 1.04s
# 117:	learn: 0.3169670	total: 1.47s	remaining: 1.02s
# 118:	learn: 0.3169131	total: 1.48s	remaining: 1.01s
# 119:	learn: 0.3167356	total: 1.49s	remaining: 994ms
# 120:	learn: 0.3166461	total: 1.5s	remaining: 979ms
# 121:	learn: 0.3166323	total: 1.51s	remaining: 965ms
# 122:	learn: 0.3165667	total: 1.52s	remaining: 950ms
# 123:	learn: 0.3165365	total: 1.53s	remaining: 936ms
# 124:	learn: 0.3164780	total: 1.54s	remaining: 922ms
# 125:	learn: 0.3164208	total: 1.55s	remaining: 909ms
# 126:	learn: 0.3163754	total: 1.56s	remaining: 895ms
# 127:	learn: 0.3163429	total: 1.56s	remaining: 881ms
# 128:	learn: 0.3163092	total: 1.57s	remaining: 867ms
# 129:	learn: 0.3162755	total: 1.58s	remaining: 852ms
# 130:	learn: 0.3162160	total: 1.59s	remaining: 839ms
# 131:	learn: 0.3161350	total: 1.6s	remaining: 826ms
# 132:	learn: 0.3160912	total: 1.61s	remaining: 813ms
# 133:	learn: 0.3160178	total: 1.63s	remaining: 801ms
# 134:	learn: 0.3159873	total: 1.64s	remaining: 789ms
# 135:	learn: 0.3159017	total: 1.65s	remaining: 776ms
# 136:	learn: 0.3157888	total: 1.66s	remaining: 763ms
# 137:	learn: 0.3157344	total: 1.67s	remaining: 749ms
# 138:	learn: 0.3156241	total: 1.68s	remaining: 736ms
# 139:	learn: 0.3155499	total: 1.69s	remaining: 723ms
# 140:	learn: 0.3154663	total: 1.7s	remaining: 709ms
# 141:	learn: 0.3153520	total: 1.7s	remaining: 696ms
# 142:	learn: 0.3152456	total: 1.71s	remaining: 683ms
# 143:	learn: 0.3151463	total: 1.72s	remaining: 670ms
# 144:	learn: 0.3151280	total: 1.73s	remaining: 657ms
# 145:	learn: 0.3150340	total: 1.74s	remaining: 644ms
# 146:	learn: 0.3149679	total: 1.75s	remaining: 631ms
# 147:	learn: 0.3148761	total: 1.76s	remaining: 618ms
# 148:	learn: 0.3148137	total: 1.77s	remaining: 605ms
# 149:	learn: 0.3147730	total: 1.78s	remaining: 592ms
# 150:	learn: 0.3147081	total: 1.78s	remaining: 579ms
# 151:	learn: 0.3146897	total: 1.79s	remaining: 567ms
# 152:	learn: 0.3146182	total: 1.8s	remaining: 555ms
# 153:	learn: 0.3145728	total: 1.82s	remaining: 544ms
# 154:	learn: 0.3145181	total: 1.83s	remaining: 532ms
# 155:	learn: 0.3144717	total: 1.84s	remaining: 520ms
# 156:	learn: 0.3143887	total: 1.85s	remaining: 507ms
# 157:	learn: 0.3142547	total: 1.86s	remaining: 495ms
# 158:	learn: 0.3141113	total: 1.88s	remaining: 485ms
# 159:	learn: 0.3140557	total: 1.9s	remaining: 474ms
# 160:	learn: 0.3139484	total: 1.91s	remaining: 462ms
# 161:	learn: 0.3139139	total: 1.92s	remaining: 450ms
# 162:	learn: 0.3139016	total: 1.93s	remaining: 437ms
# 163:	learn: 0.3138541	total: 1.93s	remaining: 425ms
# 164:	learn: 0.3137600	total: 1.94s	remaining: 413ms
# 165:	learn: 0.3137074	total: 1.95s	remaining: 400ms
# 166:	learn: 0.3136326	total: 1.96s	remaining: 388ms
# 167:	learn: 0.3135464	total: 1.97s	remaining: 376ms
# 168:	learn: 0.3135326	total: 1.98s	remaining: 363ms
# 169:	learn: 0.3134748	total: 1.99s	remaining: 351ms
# 170:	learn: 0.3133979	total: 2s	remaining: 339ms
# 171:	learn: 0.3133082	total: 2.01s	remaining: 327ms
# 172:	learn: 0.3132746	total: 2.02s	remaining: 315ms
# 173:	learn: 0.3131999	total: 2.03s	remaining: 304ms
# 174:	learn: 0.3131387	total: 2.04s	remaining: 292ms
# 175:	learn: 0.3130965	total: 2.05s	remaining: 280ms
# 176:	learn: 0.3130597	total: 2.06s	remaining: 268ms
# 177:	learn: 0.3129102	total: 2.07s	remaining: 256ms
# 178:	learn: 0.3128286	total: 2.08s	remaining: 244ms
# 179:	learn: 0.3126798	total: 2.09s	remaining: 232ms
# 180:	learn: 0.3126285	total: 2.1s	remaining: 221ms
# 181:	learn: 0.3125802	total: 2.11s	remaining: 209ms
# 182:	learn: 0.3124939	total: 2.12s	remaining: 197ms
# 183:	learn: 0.3124304	total: 2.13s	remaining: 185ms
# 184:	learn: 0.3123587	total: 2.14s	remaining: 173ms
# 185:	learn: 0.3123210	total: 2.15s	remaining: 162ms
# 186:	learn: 0.3121856	total: 2.17s	remaining: 151ms
# 187:	learn: 0.3121109	total: 2.18s	remaining: 139ms
# 188:	learn: 0.3120342	total: 2.2s	remaining: 128ms
# 189:	learn: 0.3119938	total: 2.21s	remaining: 117ms
# 190:	learn: 0.3119534	total: 2.23s	remaining: 105ms
# 191:	learn: 0.3119111	total: 2.25s	remaining: 93.7ms
# 192:	learn: 0.3118591	total: 2.26s	remaining: 82.1ms
# 193:	learn: 0.3117813	total: 2.28s	remaining: 70.5ms
# 194:	learn: 0.3115919	total: 2.29s	remaining: 58.8ms
# 195:	learn: 0.3115720	total: 2.31s	remaining: 47.1ms
# 196:	learn: 0.3114621	total: 2.32s	remaining: 35.4ms
# 197:	learn: 0.3113535	total: 2.34s	remaining: 23.6ms
# 198:	learn: 0.3112383	total: 2.35s	remaining: 11.8ms
# 199:	learn: 0.3111151	total: 2.37s	remaining: 0us

# %%
preds = model_cat.predict_proba(X_test)[:, 1]
preds[:10]
# Out:
# array([0.91071222, 0.97649529, 0.08682014, 0.11601149, 0.09778327,
#        0.91052438, 0.17879344, 0.90427808, 0.80067923, 0.14568389])

# %%
from sklearn.metrics import f1_score, roc_auc_score, precision_score, classification_report, precision_recall_curve, confusion_matrix

# %%
precision, recall, thresholds = precision_recall_curve(y_test, preds)

fscore = (2 * precision * recall) / (precision + recall)

ix = np.argmax(fscore)
print(f'Best Threshold={thresholds[ix]}, F-Score={fscore[ix]:.3f}, Precision={precision[ix]:.3f}, Recall={recall[ix]:.3f}')
# Out:
# Best Threshold=0.6039962112537884, F-Score=0.896, Precision=0.882, Recall=0.909

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\alisa\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy in c:\users\alisa\anaconda3\lib\site-packages (from xgboost) (1.20.1)
# Requirement already satisfied: scipy in c:\users\alisa\anaconda3\lib\site-packages (from xgboost) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

params = {
    'max_depth': 4,
    'eta': 0.01,
    'subsample': 0.4,
    'min_child_weight': 7,
    'n': 580,
}

# %%
X = df_train_feat_scaled.drop(['buy_time'], axis = 1)
y = df_train_feat['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 1)

# %%
model_xgb = xgb.XGBClassifier(params=params, random_seed = 1)

# %%
model_xgb.fit(X_train, y_train)
# Out:
# [19:06:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "params", "random_seed" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1,
#               params={'eta': 0.01, 'max_depth': 4, 'min_child_weight': 7,
#                       'n': 580, 'subsample': 0.4},
#               predictor='auto', random_seed=1, random_state=0, ...)

# %%
preds = model_xgb.predict_proba(X_test)[:, 1]
preds[:10]
# Out:
# array([0.7211797 , 0.6622319 , 0.22508654, 0.13426228, 0.22755662,
#        0.9187575 , 0.2397975 , 0.9511618 , 0.8576836 , 0.16798325],
#       dtype=float32)

# %%
precision, recall, thresholds = precision_recall_curve(y_test, preds)

fscore = (2 * precision * recall) / (precision + recall)

ix = np.argmax(fscore)
print(f'Best Threshold={thresholds[ix]}, F-Score={fscore[ix]:.3f}, Precision={precision[ix]:.3f}, Recall={recall[ix]:.3f}')
# Out:
# Best Threshold=0.5345136523246765, F-Score=0.823, Precision=0.860, Recall=0.788

# %% [markdown]
# Таким образом, отдаем предпочтение модели **СatBoost**

# %% [markdown]
# Есть подозрение, что в таблице признаков в колонке 252 скрыт таргет. Проверим себя. Обучим модель без этой колонки.

# %%
df_train_feat_scaled_without_252 = df_train_feat_scaled.drop(['252'], axis = 1)

# %%
X = df_train_feat_scaled_without_252
y = df_train_feat['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 1)

# %%
model_cat_2 = CatBoostClassifier(
    random_seed=1,
    iterations=200,
    learning_rate=0.05
)

model_cat_2.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6535070	total: 9.37ms	remaining: 1.86s
# 1:	learn: 0.6141578	total: 18.8ms	remaining: 1.86s
# 2:	learn: 0.5837308	total: 27.7ms	remaining: 1.82s
# 3:	learn: 0.5531385	total: 37.2ms	remaining: 1.82s
# 4:	learn: 0.5264003	total: 46.8ms	remaining: 1.82s
# 5:	learn: 0.5048367	total: 56.3ms	remaining: 1.82s
# 6:	learn: 0.4840947	total: 65.5ms	remaining: 1.81s
# 7:	learn: 0.4664190	total: 74.8ms	remaining: 1.79s
# 8:	learn: 0.4529799	total: 83.7ms	remaining: 1.77s
# 9:	learn: 0.4412161	total: 92.5ms	remaining: 1.76s
# 10:	learn: 0.4279703	total: 101ms	remaining: 1.74s
# 11:	learn: 0.4180022	total: 110ms	remaining: 1.72s
# 12:	learn: 0.4088818	total: 119ms	remaining: 1.72s
# 13:	learn: 0.4003136	total: 128ms	remaining: 1.7s
# 14:	learn: 0.3927442	total: 137ms	remaining: 1.69s
# 15:	learn: 0.3864884	total: 146ms	remaining: 1.68s
# 16:	learn: 0.3817418	total: 155ms	remaining: 1.67s
# 17:	learn: 0.3758048	total: 164ms	remaining: 1.66s
# 18:	learn: 0.3692048	total: 173ms	remaining: 1.65s
# 19:	learn: 0.3659883	total: 184ms	remaining: 1.66s
# 20:	learn: 0.3609975	total: 194ms	remaining: 1.66s
# 21:	learn: 0.3578329	total: 207ms	remaining: 1.67s
# 22:	learn: 0.3546132	total: 220ms	remaining: 1.69s
# 23:	learn: 0.3517744	total: 229ms	remaining: 1.68s
# 24:	learn: 0.3492555	total: 240ms	remaining: 1.68s
# 25:	learn: 0.3472413	total: 249ms	remaining: 1.66s
# 26:	learn: 0.3450499	total: 258ms	remaining: 1.65s
# 27:	learn: 0.3431349	total: 267ms	remaining: 1.64s
# 28:	learn: 0.3415269	total: 277ms	remaining: 1.63s
# 29:	learn: 0.3391587	total: 286ms	remaining: 1.62s
# 30:	learn: 0.3380714	total: 297ms	remaining: 1.62s
# 31:	learn: 0.3369572	total: 306ms	remaining: 1.6s
# 32:	learn: 0.3359676	total: 317ms	remaining: 1.61s
# 33:	learn: 0.3353444	total: 329ms	remaining: 1.61s
# 34:	learn: 0.3347373	total: 339ms	remaining: 1.6s
# 35:	learn: 0.3341039	total: 348ms	remaining: 1.59s
# 36:	learn: 0.3335852	total: 358ms	remaining: 1.58s
# 37:	learn: 0.3328581	total: 367ms	remaining: 1.56s
# 38:	learn: 0.3323396	total: 377ms	remaining: 1.56s
# 39:	learn: 0.3316854	total: 387ms	remaining: 1.55s
# 40:	learn: 0.3312828	total: 399ms	remaining: 1.54s
# 41:	learn: 0.3305173	total: 413ms	remaining: 1.55s
# 42:	learn: 0.3299802	total: 423ms	remaining: 1.54s
# 43:	learn: 0.3295318	total: 433ms	remaining: 1.53s
# 44:	learn: 0.3290119	total: 442ms	remaining: 1.52s
# 45:	learn: 0.3282440	total: 452ms	remaining: 1.51s
# 46:	learn: 0.3278517	total: 461ms	remaining: 1.5s
# 47:	learn: 0.3276559	total: 471ms	remaining: 1.49s
# 48:	learn: 0.3275471	total: 480ms	remaining: 1.48s
# 49:	learn: 0.3273354	total: 489ms	remaining: 1.47s
# 50:	learn: 0.3271796	total: 498ms	remaining: 1.46s
# 51:	learn: 0.3269884	total: 508ms	remaining: 1.44s
# 52:	learn: 0.3268571	total: 517ms	remaining: 1.43s
# 53:	learn: 0.3263333	total: 526ms	remaining: 1.42s
# 54:	learn: 0.3262227	total: 534ms	remaining: 1.41s
# 55:	learn: 0.3255737	total: 543ms	remaining: 1.4s
# 56:	learn: 0.3254059	total: 553ms	remaining: 1.39s
# 57:	learn: 0.3249001	total: 562ms	remaining: 1.38s
# 58:	learn: 0.3246993	total: 571ms	remaining: 1.36s
# 59:	learn: 0.3244965	total: 584ms	remaining: 1.36s
# 60:	learn: 0.3243854	total: 596ms	remaining: 1.36s
# 61:	learn: 0.3239972	total: 605ms	remaining: 1.35s
# 62:	learn: 0.3237184	total: 615ms	remaining: 1.34s
# 63:	learn: 0.3236356	total: 624ms	remaining: 1.33s
# 64:	learn: 0.3234210	total: 633ms	remaining: 1.31s
# 65:	learn: 0.3231674	total: 645ms	remaining: 1.31s
# 66:	learn: 0.3230482	total: 662ms	remaining: 1.31s
# 67:	learn: 0.3228902	total: 678ms	remaining: 1.32s
# 68:	learn: 0.3226285	total: 687ms	remaining: 1.3s
# 69:	learn: 0.3223216	total: 696ms	remaining: 1.29s
# 70:	learn: 0.3221266	total: 705ms	remaining: 1.28s
# 71:	learn: 0.3219821	total: 714ms	remaining: 1.27s
# 72:	learn: 0.3218884	total: 723ms	remaining: 1.26s
# 73:	learn: 0.3216615	total: 732ms	remaining: 1.25s
# 74:	learn: 0.3215188	total: 741ms	remaining: 1.23s
# 75:	learn: 0.3214377	total: 749ms	remaining: 1.22s
# 76:	learn: 0.3211466	total: 758ms	remaining: 1.21s
# 77:	learn: 0.3211110	total: 767ms	remaining: 1.2s
# 78:	learn: 0.3209463	total: 783ms	remaining: 1.2s
# 79:	learn: 0.3208722	total: 796ms	remaining: 1.19s
# 80:	learn: 0.3207673	total: 806ms	remaining: 1.18s
# 81:	learn: 0.3206972	total: 815ms	remaining: 1.17s
# 82:	learn: 0.3206239	total: 824ms	remaining: 1.16s
# 83:	learn: 0.3204897	total: 833ms	remaining: 1.15s
# 84:	learn: 0.3204126	total: 843ms	remaining: 1.14s
# 85:	learn: 0.3202441	total: 852ms	remaining: 1.13s
# 86:	learn: 0.3201018	total: 862ms	remaining: 1.12s
# 87:	learn: 0.3200227	total: 873ms	remaining: 1.11s
# 88:	learn: 0.3198924	total: 882ms	remaining: 1.1s
# 89:	learn: 0.3198457	total: 893ms	remaining: 1.09s
# 90:	learn: 0.3197923	total: 904ms	remaining: 1.08s
# 91:	learn: 0.3196946	total: 914ms	remaining: 1.07s
# 92:	learn: 0.3195497	total: 923ms	remaining: 1.06s
# 93:	learn: 0.3193764	total: 933ms	remaining: 1.05s
# 94:	learn: 0.3192571	total: 942ms	remaining: 1.04s
# 95:	learn: 0.3191873	total: 950ms	remaining: 1.03s
# 96:	learn: 0.3190988	total: 959ms	remaining: 1.02s
# 97:	learn: 0.3190098	total: 970ms	remaining: 1.01s
# 98:	learn: 0.3189627	total: 982ms	remaining: 1s
# 99:	learn: 0.3188866	total: 991ms	remaining: 991ms
# 100:	learn: 0.3188288	total: 1s	remaining: 981ms
# 101:	learn: 0.3186269	total: 1.01s	remaining: 973ms
# 102:	learn: 0.3185859	total: 1.02s	remaining: 963ms
# 103:	learn: 0.3184120	total: 1.03s	remaining: 952ms
# 104:	learn: 0.3183241	total: 1.04s	remaining: 941ms
# 105:	learn: 0.3181021	total: 1.05s	remaining: 931ms
# 106:	learn: 0.3180176	total: 1.06s	remaining: 922ms
# 107:	learn: 0.3179425	total: 1.07s	remaining: 914ms
# 108:	learn: 0.3178917	total: 1.08s	remaining: 903ms
# 109:	learn: 0.3178243	total: 1.09s	remaining: 892ms
# 110:	learn: 0.3177405	total: 1.1s	remaining: 881ms
# 111:	learn: 0.3176577	total: 1.11s	remaining: 871ms
# 112:	learn: 0.3175107	total: 1.12s	remaining: 861ms
# 113:	learn: 0.3174578	total: 1.13s	remaining: 851ms
# 114:	learn: 0.3172916	total: 1.14s	remaining: 841ms
# 115:	learn: 0.3172333	total: 1.15s	remaining: 832ms
# 116:	learn: 0.3171336	total: 1.16s	remaining: 822ms
# 117:	learn: 0.3170325	total: 1.17s	remaining: 814ms
# 118:	learn: 0.3169704	total: 1.18s	remaining: 806ms
# 119:	learn: 0.3169279	total: 1.2s	remaining: 797ms
# 120:	learn: 0.3165983	total: 1.21s	remaining: 787ms
# 121:	learn: 0.3165003	total: 1.22s	remaining: 779ms
# 122:	learn: 0.3164503	total: 1.23s	remaining: 771ms
# 123:	learn: 0.3163860	total: 1.24s	remaining: 760ms
# 124:	learn: 0.3162879	total: 1.25s	remaining: 749ms
# 125:	learn: 0.3162236	total: 1.26s	remaining: 739ms
# 126:	learn: 0.3161610	total: 1.27s	remaining: 729ms
# 127:	learn: 0.3159465	total: 1.28s	remaining: 718ms
# 128:	learn: 0.3158845	total: 1.28s	remaining: 708ms
# 129:	learn: 0.3157916	total: 1.3s	remaining: 699ms
# 130:	learn: 0.3156676	total: 1.31s	remaining: 690ms
# 131:	learn: 0.3155971	total: 1.32s	remaining: 679ms
# 132:	learn: 0.3155171	total: 1.33s	remaining: 669ms
# 133:	learn: 0.3154265	total: 1.34s	remaining: 658ms
# 134:	learn: 0.3152968	total: 1.35s	remaining: 648ms
# 135:	learn: 0.3152701	total: 1.35s	remaining: 637ms
# 136:	learn: 0.3151231	total: 1.36s	remaining: 627ms
# 137:	learn: 0.3150921	total: 1.38s	remaining: 618ms
# 138:	learn: 0.3150193	total: 1.39s	remaining: 609ms
# 139:	learn: 0.3149354	total: 1.4s	remaining: 599ms
# 140:	learn: 0.3148913	total: 1.41s	remaining: 589ms
# 141:	learn: 0.3148041	total: 1.42s	remaining: 579ms
# 142:	learn: 0.3146513	total: 1.43s	remaining: 569ms
# 143:	learn: 0.3145464	total: 1.44s	remaining: 559ms
# 144:	learn: 0.3144869	total: 1.45s	remaining: 548ms
# 145:	learn: 0.3143437	total: 1.46s	remaining: 539ms
# 146:	learn: 0.3143043	total: 1.47s	remaining: 529ms
# 147:	learn: 0.3142321	total: 1.48s	remaining: 518ms
# 148:	learn: 0.3141028	total: 1.49s	remaining: 509ms
# 149:	learn: 0.3140276	total: 1.5s	remaining: 498ms
# 150:	learn: 0.3139684	total: 1.5s	remaining: 488ms
# 151:	learn: 0.3139157	total: 1.51s	remaining: 478ms
# 152:	learn: 0.3138208	total: 1.52s	remaining: 468ms
# 153:	learn: 0.3137635	total: 1.53s	remaining: 458ms
# 154:	learn: 0.3137119	total: 1.54s	remaining: 448ms
# 155:	learn: 0.3136199	total: 1.55s	remaining: 438ms
# 156:	learn: 0.3135538	total: 1.56s	remaining: 428ms
# 157:	learn: 0.3133191	total: 1.57s	remaining: 418ms
# 158:	learn: 0.3132846	total: 1.58s	remaining: 408ms
# 159:	learn: 0.3132228	total: 1.59s	remaining: 398ms
# 160:	learn: 0.3131562	total: 1.6s	remaining: 389ms
# 161:	learn: 0.3130772	total: 1.61s	remaining: 379ms
# 162:	learn: 0.3130396	total: 1.62s	remaining: 369ms
# 163:	learn: 0.3129776	total: 1.63s	remaining: 358ms
# 164:	learn: 0.3128344	total: 1.64s	remaining: 348ms
# 165:	learn: 0.3127513	total: 1.65s	remaining: 339ms
# 166:	learn: 0.3126384	total: 1.67s	remaining: 330ms
# 167:	learn: 0.3125802	total: 1.69s	remaining: 322ms
# 168:	learn: 0.3124702	total: 1.7s	remaining: 312ms
# 169:	learn: 0.3124448	total: 1.71s	remaining: 302ms
# 170:	learn: 0.3123499	total: 1.72s	remaining: 292ms
# 171:	learn: 0.3122778	total: 1.73s	remaining: 281ms
# 172:	learn: 0.3119089	total: 1.74s	remaining: 271ms
# 173:	learn: 0.3118306	total: 1.75s	remaining: 261ms
# 174:	learn: 0.3117232	total: 1.76s	remaining: 251ms
# 175:	learn: 0.3117130	total: 1.77s	remaining: 241ms
# 176:	learn: 0.3115604	total: 1.78s	remaining: 231ms
# 177:	learn: 0.3114837	total: 1.79s	remaining: 222ms
# 178:	learn: 0.3113627	total: 1.8s	remaining: 212ms
# 179:	learn: 0.3112406	total: 1.81s	remaining: 202ms
# 180:	learn: 0.3112141	total: 1.82s	remaining: 191ms
# 181:	learn: 0.3111367	total: 1.83s	remaining: 182ms
# 182:	learn: 0.3110582	total: 1.85s	remaining: 172ms
# 183:	learn: 0.3109567	total: 1.86s	remaining: 162ms
# 184:	learn: 0.3108767	total: 1.88s	remaining: 153ms
# 185:	learn: 0.3107923	total: 1.9s	remaining: 143ms
# 186:	learn: 0.3107527	total: 1.91s	remaining: 133ms
# 187:	learn: 0.3106546	total: 1.93s	remaining: 123ms
# 188:	learn: 0.3106427	total: 1.94s	remaining: 113ms
# 189:	learn: 0.3105601	total: 1.95s	remaining: 103ms
# 190:	learn: 0.3105239	total: 1.97s	remaining: 92.9ms
# 191:	learn: 0.3103776	total: 1.99s	remaining: 82.9ms
# 192:	learn: 0.3102510	total: 2.01s	remaining: 72.8ms
# 193:	learn: 0.3101636	total: 2.02s	remaining: 62.5ms
# 194:	learn: 0.3101104	total: 2.04s	remaining: 52.2ms
# 195:	learn: 0.3100301	total: 2.05s	remaining: 41.9ms
# 196:	learn: 0.3099544	total: 2.06s	remaining: 31.5ms
# 197:	learn: 0.3098864	total: 2.08s	remaining: 21ms
# 198:	learn: 0.3098258	total: 2.1s	remaining: 10.5ms
# 199:	learn: 0.3097666	total: 2.11s	remaining: 0us

# %%
preds = model_cat_2.predict_proba(X_test)[:, 1]
preds[:10]
# Out:
# array([0.91265781, 0.9749781 , 0.07804904, 0.11892619, 0.1019637 ,
#        0.90353968, 0.17863238, 0.91234112, 0.80493021, 0.13532812])

# %%
precision, recall, thresholds = precision_recall_curve(y_test, preds)

fscore = (2 * precision * recall) / (precision + recall)

ix = np.argmax(fscore)
print(f'Best Threshold={thresholds[ix]}, F-Score={fscore[ix]:.3f}, Precision={precision[ix]:.3f}, Recall={recall[ix]:.3f}')
# Out:
# Best Threshold=0.5967780948808138, F-Score=0.895, Precision=0.882, Recall=0.909

# %% [markdown]
# Показатели изменились незначительно. Следовательно 252 не была колонкой, которая слишком сильно влияла на модель.

# %% [markdown]
# **Сохраняем модель**

# %%
import pickle

# %%
from pathlib import Path

# %%
filepath = r'C:/Users/features/model_Pickle.pkl'
pickle.dump(model_cat, open(filepath, 'wb'))

# %% [markdown]
# **Сохраняем датасет с прогнозом**: вероятностью подключения услуги

# %%
preds_new = model_cat.predict_proba(df_test_feat_scaled)[:, 1]

# %%
preds_new = pd.DataFrame(preds_new, columns = ['positive_probability'])

# %%
preds_new.head(3)
# Out:
#    positive_probability
# 0              0.018962
# 1              0.013876
# 2              0.009507

# %%
answers_test = pd.concat([df_test, preds_new], axis = 1)

# %%
answers_test.head(3)
# Out:
#         id  vas_id    buy_time  positive_probability
# 0  3130519     2.0  1548018000              0.018962
# 1  2000860     4.0  1548018000              0.013876
# 2  1099444     2.0  1546808400              0.009507

# %%
answers_test.to_csv('C:/Users/features/answers_test.csv', sep='\t')
